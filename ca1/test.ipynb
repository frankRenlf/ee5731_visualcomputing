# %%
import numpy as np


def fx(x):
    return x * np.log2(1 / x)


li = [8.4 %, 1.5 %, 2.2 %, 4.2 %, 11 %, 2.2 %, 2 %, 6 %, 7.4 %, 0.1 %, 1.3 %, 4 %, 2.4 %, 6.7 %, 7.4 %, 1.9 %, 0.1 %,
      7.5 %, 6.2 %, 9.2 %, 2.7 %, 0.9 %, 2.5 %, 0.1 %, 2 %, 0.1 %]
num = 0
for j in li:
    num += fx(j)
print(num)
